# %%
# %cd ../..
# %load_ext autoreload
# %autoreload 2
# Out:
# /root/capsule/code

# %%
from pipeline.export import to_s3
from pipeline import experiment, lab
import datajoint as dj; dj.conn().connect()

# %%
to_s3.export_df_foraging_sessions()
to_s3.export_df_regressions()
to_s3.export_df_model_fitting_param()
# Out:
# file exported to Han/ephys/report/st_cache/df_sessions.pkl, size = 1.1612730026245117 MB, df_length = 3001
# file exported to Han/ephys/report/st_cache/df_linear_regression_rt.pkl, size = 3.0565595626831055 MB, df_length = 44408
# file exported to Han/ephys/report/st_cache/df_logistic_regression_hattori.pkl, size = 6.779356956481934 MB, df_length = 105440
# file exported to Han/ephys/report/st_cache/df_logistic_regression_su.pkl, size = 4.768707275390625 MB, df_length = 72468
# file exported to Han/ephys/report/st_cache/df_model_fitting_params.pkl, size = 4.112431526184082 MB, df_length = 19243
#       subject_id  session  model_id  n_trials  n_params  log_likelihood  \
# 0         447921        3         8       702         3        -471.210
# 1         447921        4         8       333         3        -165.151
# 2         447921        5         8       394         3        -206.619
# 3         447921        6         8       791         3        -478.809
# ...

# %%
lab.Person()
# Out:
# *username    fullname
# +----------+ +----------------+
# daiek        Kayvon Daie
# daveliu      Dave Liu
# HH           Han Hou
# Kenta        Kenta Hagihara
# liangy10     Yajie Liang
# Linda        Linda Amarante
# Lucas        Lucas Kinsey
# Lucas K      Lucas Kinsey
# LucasK       Lucas Kinsey
# NT           Nai-Wen Tien
# rozsam       Marton Rozsa
# singha       Amrita Singh
# Smrithi      Smrithi Sunil
# susu         Susu Chen
# Tina         Tina Pluntke
# Xinxin       Xinxin Yin
#  (Total: 16)

# %%
import boto3

# %%
s3 = boto3.resource('s3')
my_bucket = s3.Bucket('aind-behavior-data')

# %%
import pandas as pd
a = pd.DataFrame([0, 1])

# %%
a.to_pickle('/root/capsule/results/temp.pkl')

# %%
def upload_file(file_name, bucket, object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = os.path.basename(file_name)

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(file_name, bucket, object_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
upload_file('/root/capsule/results/temp.pkl', 'aind-behavior-data', 'Han/ephys/report/temp.pkl')
# Out:
# True

# %%
from pipeline.export import to_s3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_659/4239464976.py in <module>
# ----> 1 from pipeline.export import to_s3
#
# ModuleNotFoundError: No module named 'pipeline'
